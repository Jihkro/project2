# %%
import pandas as pd

# %%
yeardata_df = pd.read_csv("finaldata_byYEAR_UPDATED.csv")
yeardata_df.head()
# Out:
#    Year  Hurricanes  Earthquakes  Floods  Tornadoes  Fires  \
# 0  1959         NaN          NaN     1.0        NaN    NaN
# 1  1964         NaN          NaN     4.0        NaN    NaN
# 2  1965         3.0          1.0     9.0        7.0    NaN
# 3  1966         NaN          NaN     9.0        1.0    NaN
# 4  1967         1.0          NaN     5.0        2.0    1.0
#
#    Total OUR Disasters  Total ALL Disasters on FEMA
# 0                    1                            1
# 1                    4                            4
# 2                   20                           25
# 3                   10                           10
# 4                    9                            9

# %%
yeardata_df.dtypes
# Out:
# Year                             int64
# Hurricanes                     float64
# Earthquakes                    float64
# Floods                         float64
# Tornadoes                      float64
# Fires                          float64
# Total OUR Disasters              int64
# Total ALL Disasters on FEMA      int64
# dtype: object

# %%
#convert all NaN with 0
newyear_df = yeardata_df.fillna(0)

# %%
newyear_df.to_dict(orient='records')
# Out:
# [{'Year': 1959.0,
#   'Hurricanes': 0.0,
#   'Earthquakes': 0.0,
#   'Floods': 1.0,
#   'Tornadoes': 0.0,
#   'Fires': 0.0,
#   'Total OUR Disasters': 1.0,
#   'Total ALL Disasters on FEMA': 1.0},
#  {'Year': 1964.0,
#   'Hurricanes': 0.0,
#   'Earthquakes': 0.0,
#   'Floods': 4.0,
#   'Tornadoes': 0.0,
#   'Fires': 0.0,
#   'Total OUR Disasters': 4.0,
#   'Total ALL Disasters on FEMA': 4.0},
#  {'Year': 1965.0,
#   'Hurricanes': 3.0,
#   'Earthquakes': 1.0,
#   'Floods': 9.0,
#   'Tornadoes': 7.0,
#   'Fires': 0.0,
#   'Total OUR Disasters': 20.0,
#   'Total ALL Disasters on FEMA': 25.0},
#  {'Year': 1966.0,
#   'Hurricanes': 0.0,
#   'Earthquakes': 0.0,
#   'Floods': 9.0,
#   'Tornadoes': 1.0,
#   'Fires': 0.0,
#   'Total OUR Disasters': 10.0,
#   'Total ALL Disasters on FEMA': 10.0},
#  {'Year': 1967.0,
#   'Hurricanes': 1.0,
#   'Earthquakes': 0.0,
#   'Floods': 5.0,
#   'Tornadoes': 2.0,
#   'Fires': 1.0,
#   'Total OUR Disasters': 9.0,
#   'Total ALL Disasters on FEMA': 9.0},
# ...
