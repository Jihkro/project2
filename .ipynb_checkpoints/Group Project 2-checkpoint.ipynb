# %%
#import dependencies
import pandas as pd
import numpy as np

# %%
#import csv files
fema_df = pd.read_csv("Resources/fema_all-disasters.csv")
fema_df.head()
# Out:
#    Disaster Number IH Program Declared IA Program Declared  \
# 0             4411                  No                  No
# 1             4411                  No                  No
# 2             4411                  No                  No
# 3             4411                  No                  No
# 4             4411                  No                  No
#
#   PA Program Declared HM Program Declared State  Declaration Date  \
# 0                 Yes                 Yes     VA       12/18/2018
# 1                 Yes                 Yes     VA       12/18/2018
# 2                 Yes                 Yes     VA       12/18/2018
# 3                 Yes                 Yes     VA       12/18/2018
# 4                 Yes                 Yes     VA       12/18/2018
#
#   Disaster Type Incident Type                   Title Incident Begin Date  \
# 0            DR     Hurricane  TROPICAL STORM MICHAEL           10/9/2018
# 1            DR     Hurricane  TROPICAL STORM MICHAEL           10/9/2018
# 2            DR     Hurricane  TROPICAL STORM MICHAEL           10/9/2018
# 3            DR     Hurricane  TROPICAL STORM MICHAEL           10/9/2018
# 4            DR     Hurricane  TROPICAL STORM MICHAEL           10/9/2018
#
#   Incident End Date Disaster Close Out Date  Place Code Declared County/Area  \
# 0        10/16/2018                     NaN     21344.0             Danville
# 1        10/16/2018                     NaN     30208.0                Galax
# 2        10/16/2018                     NaN     99007.0      Amelia (County)
# 3        10/16/2018                     NaN     99011.0  Appomattox (County)
# 4        10/16/2018                     NaN     99025.0   Brunswick (County)
#
#    Declaration Request Number
# 0                       18134
# 1                       18134
# 2                       18134
# 3                       18134
# 4                       18134

# %%
#merge in state codes 
state_df = pd.read_csv("Resources/state_codes.csv")
disaster_df = pd.merge(fema_df, state_df, on=["State "])
disaster_df.head()
# Out:
#    Disaster Number IH Program Declared IA Program Declared  \
# 0             4411                  No                  No
# 1             4411                  No                  No
# 2             4411                  No                  No
# 3             4411                  No                  No
# 4             4411                  No                  No
#
#   PA Program Declared HM Program Declared State  Declaration Date  \
# 0                 Yes                 Yes     VA       12/18/2018
# 1                 Yes                 Yes     VA       12/18/2018
# 2                 Yes                 Yes     VA       12/18/2018
# 3                 Yes                 Yes     VA       12/18/2018
# 4                 Yes                 Yes     VA       12/18/2018
#
#   Disaster Type Incident Type                   Title Incident Begin Date  \
# 0            DR     Hurricane  TROPICAL STORM MICHAEL           10/9/2018
# 1            DR     Hurricane  TROPICAL STORM MICHAEL           10/9/2018
# 2            DR     Hurricane  TROPICAL STORM MICHAEL           10/9/2018
# 3            DR     Hurricane  TROPICAL STORM MICHAEL           10/9/2018
# 4            DR     Hurricane  TROPICAL STORM MICHAEL           10/9/2018
#
#   Incident End Date Disaster Close Out Date  Place Code Declared County/Area  \
# 0        10/16/2018                     NaN     21344.0             Danville
# 1        10/16/2018                     NaN     30208.0                Galax
# 2        10/16/2018                     NaN     99007.0      Amelia (County)
# 3        10/16/2018                     NaN     99011.0  Appomattox (County)
# 4        10/16/2018                     NaN     99025.0   Brunswick (County)
#
#    Declaration Request Number  State Code
# 0                       18134          51
# 1                       18134          51
# 2                       18134          51
# 3                       18134          51
# 4                       18134          51

# %%
#get list of column name
list(disaster_df.columns.values)
# Out:
# ['Disaster Number',
#  'IH Program Declared',
#  'IA Program Declared',
#  'PA Program Declared',
#  'HM Program Declared',
#  'State ',
#  'Declaration Date',
#  'Disaster Type',
#  'Incident Type',
#  'Title',
#  'Incident Begin Date',
#  'Incident End Date',
#  'Disaster Close Out Date',
#  'Place Code',
#  'Declared County/Area',
#  'Declaration Request Number',
#  'State Code']

# %%
#Cut columns we don't need out of dataframe
new_cols = ["Disaster Type", "Incident Type","Title","Incident Begin Date", "State ", "State Code","Declared County/Area", "Place Code", ]
disaster_df2 = disaster_df[new_cols].copy()
disaster_df2.head()
# Out:
#   Disaster Type Incident Type                   Title Incident Begin Date  \
# 0            DR     Hurricane  TROPICAL STORM MICHAEL           10/9/2018
# 1            DR     Hurricane  TROPICAL STORM MICHAEL           10/9/2018
# 2            DR     Hurricane  TROPICAL STORM MICHAEL           10/9/2018
# 3            DR     Hurricane  TROPICAL STORM MICHAEL           10/9/2018
# 4            DR     Hurricane  TROPICAL STORM MICHAEL           10/9/2018
#
#   State   State Code Declared County/Area  Place Code
# 0     VA          51             Danville     21344.0
# 1     VA          51                Galax     30208.0
# 2     VA          51      Amelia (County)     99007.0
# 3     VA          51  Appomattox (County)     99011.0
# 4     VA          51   Brunswick (County)     99025.0

# %%
#set data types
disaster_df2.dtypes
# Out:
# Disaster Type            object
# Incident Type            object
# Title                    object
# Incident Begin Date      object
# State                    object
# State Code                int64
# Declared County/Area     object
# Place Code              float64
# dtype: object

# %%
#convert all d-types to strings so we can manipulate them easily later
disaster_df2["State Code"] = disaster_df2["State Code"].astype(str)
disaster_df2["Place Code"] = disaster_df2["Place Code"].astype(str)
disaster_df2.dtypes
# Out:
# Disaster Type           object
# Incident Type           object
# Title                   object
# Incident Begin Date     object
# State                   object
# State Code              object
# Declared County/Area    object
# Place Code              object
# dtype: object

# %%
#isolate data for Marjor Disasters ('Disaster Type' = DR)
disaster_df2["Disaster Type"].unique()
# Out:
# array(['DR', 'EM', 'FM', 'FS'], dtype=object)

# %%
majordisaster_df = disaster_df2.loc[disaster_df2["Disaster Type"] == "DR"]
majordisaster_df.head()
# Out:
#   Disaster Type Incident Type                   Title Incident Begin Date  \
# 0            DR     Hurricane  TROPICAL STORM MICHAEL           10/9/2018
# 1            DR     Hurricane  TROPICAL STORM MICHAEL           10/9/2018
# 2            DR     Hurricane  TROPICAL STORM MICHAEL           10/9/2018
# 3            DR     Hurricane  TROPICAL STORM MICHAEL           10/9/2018
# 4            DR     Hurricane  TROPICAL STORM MICHAEL           10/9/2018
#
#   State  State Code Declared County/Area Place Code
# 0     VA         51             Danville    21344.0
# 1     VA         51                Galax    30208.0
# 2     VA         51      Amelia (County)    99007.0
# 3     VA         51  Appomattox (County)    99011.0
# 4     VA         51   Brunswick (County)    99025.0

# %%
#remove all place codes for unincorporated areas and for areas missing specific county data
#remove place codes that do not start with 99-
majordisaster_df2 = majordisaster_df.loc[majordisaster_df["Place Code"]>"99000"]

#remove place codes that are NaN
disaster_final = majordisaster_df2.dropna()
disaster_final.head()
# Out:
#   Disaster Type Incident Type                   Title Incident Begin Date  \
# 2            DR     Hurricane  TROPICAL STORM MICHAEL           10/9/2018
# 3            DR     Hurricane  TROPICAL STORM MICHAEL           10/9/2018
# 4            DR     Hurricane  TROPICAL STORM MICHAEL           10/9/2018
# 5            DR     Hurricane  TROPICAL STORM MICHAEL           10/9/2018
# 6            DR     Hurricane  TROPICAL STORM MICHAEL           10/9/2018
#
#   State  State Code Declared County/Area Place Code
# 2     VA         51      Amelia (County)    99007.0
# 3     VA         51  Appomattox (County)    99011.0
# 4     VA         51   Brunswick (County)    99025.0
# 5     VA         51    Campbell (County)    99031.0
# 6     VA         51   Charlotte (County)    99037.0

# %%
#remove 99- from beginning of remaining Place Copdes (new 3 digit value = County FIPS Code)
disaster_final['Place Code'] = disaster_final['Place Code'].str[2:5]
disaster_final
# Out:
# C:\Users\Anum Ali\Anaconda3\lib\site-packages\ipykernel\__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
#       Disaster Type Incident Type                                Title  \
# 2                DR     Hurricane               TROPICAL STORM MICHAEL
# 3                DR     Hurricane               TROPICAL STORM MICHAEL
# 4                DR     Hurricane               TROPICAL STORM MICHAEL
# 5                DR     Hurricane               TROPICAL STORM MICHAEL
# 6                DR     Hurricane               TROPICAL STORM MICHAEL
# 7                DR     Hurricane               TROPICAL STORM MICHAEL
# 8                DR     Hurricane               TROPICAL STORM MICHAEL
# 9                DR     Hurricane               TROPICAL STORM MICHAEL
# 10               DR     Hurricane               TROPICAL STORM MICHAEL
# 11               DR     Hurricane               TROPICAL STORM MICHAEL
# 12               DR     Hurricane               TROPICAL STORM MICHAEL
# 13               DR     Hurricane               TROPICAL STORM MICHAEL
# 14               DR     Hurricane               TROPICAL STORM MICHAEL
# 15               DR     Hurricane               TROPICAL STORM MICHAEL
# 16               DR     Hurricane               TROPICAL STORM MICHAEL
# 17               DR     Hurricane               TROPICAL STORM MICHAEL
# 18               DR     Hurricane               TROPICAL STORM MICHAEL
# 19               DR     Hurricane               TROPICAL STORM MICHAEL
# 20               DR     Hurricane               TROPICAL STORM MICHAEL
# 21               DR     Hurricane               TROPICAL STORM MICHAEL
# 22               DR     Hurricane               TROPICAL STORM MICHAEL
# 23               DR     Hurricane               TROPICAL STORM MICHAEL
# 24               DR     Hurricane               TROPICAL STORM MICHAEL
# 25               DR     Hurricane               TROPICAL STORM MICHAEL
# 26               DR     Hurricane               TROPICAL STORM MICHAEL
# 36               DR     Hurricane                   HURRICANE FLORENCE
# 37               DR     Hurricane                   HURRICANE FLORENCE
# 38               DR     Hurricane                   HURRICANE FLORENCE
# 39               DR     Hurricane                   HURRICANE FLORENCE
# 40               DR     Hurricane                   HURRICANE FLORENCE
# ...             ...           ...                                  ...
# 48200            DR         Flood                             FLOODING
# 48201            DR         Flood                             FLOODING
# 48202            DR         Flood                             FLOODING
# 48203            DR       Tornado  TORNADOES, SEVERE STORMS & FLOODING
# 48204            DR       Tornado  TORNADOES, SEVERE STORMS & FLOODING
# 48205            DR       Tornado  TORNADOES, SEVERE STORMS & FLOODING
# 48206            DR       Tornado  TORNADOES, SEVERE STORMS & FLOODING
# 48207            DR       Tornado  TORNADOES, SEVERE STORMS & FLOODING
# 48208            DR       Tornado  TORNADOES, SEVERE STORMS & FLOODING
# 48209            DR       Tornado  TORNADOES, SEVERE STORMS & FLOODING
# 48210            DR       Tornado  TORNADOES, SEVERE STORMS & FLOODING
# 48211            DR       Tornado                            TORNADOES
# 48212            DR       Tornado                            TORNADOES
# 48213            DR       Tornado                            TORNADOES
# 48214            DR       Tornado                            TORNADOES
# 48215            DR       Tornado                            TORNADOES
# 48216            DR       Tornado                            TORNADOES
# 48217            DR       Tornado                            TORNADOES
# 48218            DR       Tornado                            TORNADOES
# 48219            DR       Tornado                            TORNADOES
# 48220            DR       Tornado  TORNADOES, SEVERE STORMS & FLOODING
# 48221            DR       Tornado  TORNADOES, SEVERE STORMS & FLOODING
# 48222            DR       Tornado  TORNADOES, SEVERE STORMS & FLOODING
# 48223            DR       Tornado  TORNADOES, SEVERE STORMS & FLOODING
# 48224            DR       Tornado  TORNADOES, SEVERE STORMS & FLOODING
# 48225            DR       Tornado  TORNADOES, SEVERE STORMS & FLOODING
# 48226            DR       Tornado  TORNADOES, SEVERE STORMS & FLOODING
# 48227            DR       Tornado  TORNADOES, SEVERE STORMS & FLOODING
# 48228            DR       Tornado  TORNADOES, SEVERE STORMS & FLOODING
# 48229            DR       Tornado  TORNADOES, SEVERE STORMS & FLOODING
#
#       Incident Begin Date State  State Code     Declared County/Area  \
# 2               10/9/2018     VA         51          Amelia (County)
# 3               10/9/2018     VA         51      Appomattox (County)
# 4               10/9/2018     VA         51       Brunswick (County)
# 5               10/9/2018     VA         51        Campbell (County)
# 6               10/9/2018     VA         51       Charlotte (County)
# 7               10/9/2018     VA         51    Chesterfield (County)
# 8               10/9/2018     VA         51      Cumberland (County)
# 9               10/9/2018     VA         51       Dinwiddie (County)
# 10              10/9/2018     VA         51           Essex (County)
# 11              10/9/2018     VA         51           Floyd (County)
# 12              10/9/2018     VA         51        Fluvanna (County)
# 13              10/9/2018     VA         51        Franklin (County)
# 14              10/9/2018     VA         51         Halifax (County)
# 15              10/9/2018     VA         51  King and Queen (County)
# 16              10/9/2018     VA         51       Lunenburg (County)
# 17              10/9/2018     VA         51      Montgomery (County)
# 18              10/9/2018     VA         51        New Kent (County)
# 19              10/9/2018     VA         51  Northumberland (County)
# 20              10/9/2018     VA         51        Nottoway (County)
# 21              10/9/2018     VA         51    Pittsylvania (County)
# 22              10/9/2018     VA         51        Powhatan (County)
# 23              10/9/2018     VA         51   Prince Edward (County)
# 24              10/9/2018     VA         51    Rappahannock (County)
# 25              10/9/2018     VA         51        Richmond (County)
# 26              10/9/2018     VA         51         Roanoke (County)
# 36               9/8/2018     VA         51       Botetourt (County)
# 37               9/8/2018     VA         51    Charles City (County)
# 38               9/8/2018     VA         51    Chesterfield (County)
# 39               9/8/2018     VA         51           Craig (County)
# 40               9/8/2018     VA         51           Floyd (County)
# ...                   ...    ...        ...                      ...
# 48200            6/6/1969     IL         17            Pike (County)
# 48201            6/6/1969     IL         17     Rock Island (County)
# 48202            6/6/1969     IL         17       Whiteside (County)
# 48203            6/5/1968     IL         17       Champaign (County)
# 48204            6/5/1968     IL         17         De Witt (County)
# 48205            6/5/1968     IL         17           Logan (County)
# 48206            6/5/1968     IL         17          McLean (County)
# 48207            6/5/1968     IL         17           Mason (County)
# 48208            6/5/1968     IL         17           Piatt (County)
# 48209            6/5/1968     IL         17       St. Clair (County)
# 48210            6/5/1968     IL         17       Vermilion (County)
# 48211           4/25/1967     IL         17           Boone (County)
# 48212           4/25/1967     IL         17            Cook (County)
# 48213           4/25/1967     IL         17          DuPage (County)
# 48214           4/25/1967     IL         17            Kane (County)
# 48215           4/25/1967     IL         17            Lake (County)
# 48216           4/25/1967     IL         17        La Salle (County)
# 48217           4/25/1967     IL         17         McHenry (County)
# 48218           4/25/1967     IL         17            Will (County)
# 48219           4/25/1967     IL         17       Winnebago (County)
# 48220           4/25/1965     IL         17           Adams (County)
# 48221           4/25/1965     IL         17         Carroll (County)
# 48222           4/25/1965     IL         17       Henderson (County)
# 48223           4/25/1965     IL         17      Jo Daviess (County)
# 48224           4/25/1965     IL         17            Lake (County)
# 48225           4/25/1965     IL         17         McHenry (County)
# 48226           4/25/1965     IL         17          Mercer (County)
# 48227           4/25/1965     IL         17            Pike (County)
# 48228           4/25/1965     IL         17     Rock Island (County)
# 48229           4/25/1965     IL         17       Whiteside (County)
#
#       Place Code
# 2            007
# 3            011
# 4            025
# 5            031
# 6            037
# 7            041
# 8            049
# 9            053
# 10           057
# 11           063
# 12           065
# 13           067
# 14           083
# 15           097
# 16           111
# 17           121
# 18           127
# 19           133
# 20           135
# 21           143
# 22           145
# 23           147
# 24           157
# 25           159
# 26           161
# 36           023
# 37           036
# 38           041
# 39           045
# 40           063
# ...          ...
# 48200        149
# 48201        161
# 48202        195
# 48203        019
# 48204        039
# 48205        107
# 48206        113
# 48207        125
# 48208        147
# 48209        163
# 48210        183
# 48211        007
# 48212        031
# 48213        043
# 48214        089
# 48215        097
# 48216        099
# 48217        111
# 48218        197
# 48219        201
# 48220        001
# 48221        015
# 48222        071
# 48223        085
# 48224        097
# 48225        111
# 48226        131
# 48227        149
# 48228        161
# 48229        195
#
# [34142 rows x 8 columns]

# %%
#Merge Values in state code + place code together to get a unique FIPS code per county 
disaster_final['FIPS Code']=disaster_final['State Code']+disaster_final['Place Code']
disaster_final.head()
# Out:
# C:\Users\Anum Ali\Anaconda3\lib\site-packages\ipykernel\__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
#   Disaster Type Incident Type                   Title Incident Begin Date  \
# 2            DR     Hurricane  TROPICAL STORM MICHAEL           10/9/2018
# 3            DR     Hurricane  TROPICAL STORM MICHAEL           10/9/2018
# 4            DR     Hurricane  TROPICAL STORM MICHAEL           10/9/2018
# 5            DR     Hurricane  TROPICAL STORM MICHAEL           10/9/2018
# 6            DR     Hurricane  TROPICAL STORM MICHAEL           10/9/2018
#
#   State  State Code Declared County/Area Place Code FIPS Code
# 2     VA         51      Amelia (County)        007     51007
# 3     VA         51  Appomattox (County)        011     51011
# 4     VA         51   Brunswick (County)        025     51025
# 5     VA         51    Campbell (County)        031     51031
# 6     VA         51   Charlotte (County)        037     51037

# %%
#Cut State Code and Place Code Columns since we have the new FIPS Code column now
new_cols = ["Disaster Type", "Incident Type","Title","Incident Begin Date", "State ", "Declared County/Area", "FIPS Code"]
disaster_final = disaster_final[new_cols].copy()
disaster_final.head()
# Out:
#   Disaster Type Incident Type                   Title Incident Begin Date  \
# 2            DR     Hurricane  TROPICAL STORM MICHAEL           10/9/2018
# 3            DR     Hurricane  TROPICAL STORM MICHAEL           10/9/2018
# 4            DR     Hurricane  TROPICAL STORM MICHAEL           10/9/2018
# 5            DR     Hurricane  TROPICAL STORM MICHAEL           10/9/2018
# 6            DR     Hurricane  TROPICAL STORM MICHAEL           10/9/2018
#
#   State  Declared County/Area FIPS Code
# 2     VA      Amelia (County)     51007
# 3     VA  Appomattox (County)     51011
# 4     VA   Brunswick (County)     51025
# 5     VA    Campbell (County)     51031
# 6     VA   Charlotte (County)     51037

# %%
#Create separate dataframes for each major disaster type we want to report on

# %%
#List of all diaster types in dataset
disaster_final["Incident Type"].unique()
# Out:
# array(['Hurricane', 'Snow', 'Severe Storm(s)', 'Earthquake', 'Terrorist',
#        'Flood', 'Freezing', 'Tornado', 'Coastal Storm', 'Fire', 'Drought',
#        'Tsunami', 'Dam/Levee Break', 'Fishing Losses', 'Severe Ice Storm',
#        'Human Cause', 'Volcano', 'Mud/Landslide', 'Typhoon', 'Other',
#        'Toxic Substances'], dtype=object)

# %%
#Create separate dataframes for each disaster type
#Hurricanes
hurricanes_df = disaster_final.loc[disaster_final["Incident Type"] == "Hurricane"]
hurricanes_df.head()
# Out:
#   Disaster Type Incident Type                   Title Incident Begin Date  \
# 2            DR     Hurricane  TROPICAL STORM MICHAEL           10/9/2018
# 3            DR     Hurricane  TROPICAL STORM MICHAEL           10/9/2018
# 4            DR     Hurricane  TROPICAL STORM MICHAEL           10/9/2018
# 5            DR     Hurricane  TROPICAL STORM MICHAEL           10/9/2018
# 6            DR     Hurricane  TROPICAL STORM MICHAEL           10/9/2018
#
#   State  Declared County/Area FIPS Code
# 2     VA      Amelia (County)     51007
# 3     VA  Appomattox (County)     51011
# 4     VA   Brunswick (County)     51025
# 5     VA    Campbell (County)     51031
# 6     VA   Charlotte (County)     51037

# %%
#Wildfires
fires_df = disaster_final.loc[disaster_final["Incident Type"] == "Fire"]
fires_df.head()
# Out:
#      Disaster Type Incident Type           Title Incident Begin Date State   \
# 2353            DR          Fire  WILDLAND FIRES            6/2/1996     AK
# 2497            DR          Fire      ASPEN FIRE           6/17/2003     AZ
# 2506            DR          Fire       WILDFIRES           6/18/2002     AZ
# 2507            DR          Fire       WILDFIRES           6/18/2002     AZ
# 2508            DR          Fire       WILDFIRES           6/18/2002     AZ
#
#              Declared County/Area FIPS Code
# 2353  Matanuska-Susitna (Borough)      2170
# 2497                Pima (County)      4019
# 2506              Apache (County)      4001
# 2507            Coconino (County)      4005
# 2508                Gila (County)      4007

# %%
#Flood
floods_df = disaster_final.loc[disaster_final["Incident Type"] == "Flood"]
floods_df.head()
# Out:
#      Disaster Type Incident Type                                       Title  \
# 1198            DR         Flood  FLOODING, HIGH WINDS, AND WIND DRIVEN RAIN
# 1199            DR         Flood  FLOODING, HIGH WINDS, AND WIND DRIVEN RAIN
# 1200            DR         Flood  FLOODING, HIGH WINDS, AND WIND DRIVEN RAIN
# 1201            DR         Flood  FLOODING, HIGH WINDS, AND WIND DRIVEN RAIN
# 1202            DR         Flood  FLOODING, HIGH WINDS, AND WIND DRIVEN RAIN
#
#      Incident Begin Date State  Declared County/Area FIPS Code
# 1198           1/19/1996     VA   Alleghany (County)     51005
# 1199           1/19/1996     VA     Augusta (County)     51015
# 1200           1/19/1996     VA        Bath (County)     51017
# 1201           1/19/1996     VA       Bland (County)     51021
# 1202           1/19/1996     VA   Botetourt (County)     51023

# %%
#Tornado
tornado_df = disaster_final.loc[disaster_final["Incident Type"] == "Tornado"]
tornado_df.head()
# Out:
#      Disaster Type Incident Type  \
# 2043            DR       Tornado
# 2044            DR       Tornado
# 2203            DR       Tornado
# 2204            DR       Tornado
# 2227            DR       Tornado
#
#                                                   Title Incident Begin Date  \
# 2043  SEVERE STORMS, TORNADOES, AND STRAIGHT-LINE WI...           5/15/2018
# 2044  SEVERE STORMS, TORNADOES, AND STRAIGHT-LINE WI...           5/15/2018
# 2203                          SEVERE STORMS & TORNADOES           7/10/1989
# 2204                          SEVERE STORMS & TORNADOES           7/10/1989
# 2227                            TORNADO & SEVERE STORMS           10/4/1979
#
#      State                                Declared County/Area FIPS Code
# 2043     CT    Fairfield (County)(in PMSA 1160,1930,5760,8040)      9001
# 2044     CT       New Haven (County)(in (P)MSA 1160,5480,8880)      9009
# 2203     CT  Litchfield (County)(in (P)MSA 1170,1930,3280,8...      9005
# 2204     CT       New Haven (County)(in (P)MSA 1160,5480,8880)      9009
# 2227     CT          Hartford (County)(in PMSA 1170,3280,5440)      9003

# %%
#Earthquake
earthq_df = disaster_final.loc[disaster_final["Incident Type"] == "Earthquake"]
earthq_df.head()
# Out:
#     Disaster Type Incident Type       Title Incident Begin Date State   \
# 342            DR    Earthquake  EARTHQUAKE           8/23/2011     VA
# 343            DR    Earthquake  EARTHQUAKE           8/23/2011     VA
# 344            DR    Earthquake  EARTHQUAKE           8/23/2011     VA
# 345            DR    Earthquake  EARTHQUAKE           8/23/2011     VA
# 346            DR    Earthquake  EARTHQUAKE           8/23/2011     VA
#
#      Declared County/Area FIPS Code
# 342    Albemarle (County)     51003
# 343     Culpeper (County)     51047
# 344     Fluvanna (County)     51065
# 345    Goochland (County)     51075
# 346  King George (County)     51099

# %%
#Create separate dataframes for each county
#How many counties are there?
len(disaster_final["FIPS Code"].unique())
# Out:
# 3143

# %%
#list of FIPS Codes
fips_list = disaster_final["FIPS Code"].unique()
fips_list
# Out:
# array(['51007', '51011', '51025', ..., '17091', '17027', '17047'],
#       dtype=object)

# %%
county_dfs = {}

#For loop to make dataframes
for county in fips_list: 
    county_dfs[county] = pd.DataFrame(disaster_final.loc[disaster_final["FIPS Code"] == county])

county_dfs["17047"].head()
# Out:
#       Disaster Type    Incident Type                                  Title  \
# 47639            DR          Tornado  SEVERE STORMS, TORNADOES AND FLOODING
# 47912            DR  Severe Storm(s)    SEVERE STORMS, TORNADOES & FLOODING
# 47935            DR          Tornado              SEVERE STORMS & TORNADOES
#
#       Incident Begin Date State  Declared County/Area FIPS Code
# 47639           4/21/2002     IL     Edwards (County)     17047
# 47912           5/15/1990     IL     Edwards (County)     17047
# 47935            1/7/1989     IL     Edwards (County)     17047
